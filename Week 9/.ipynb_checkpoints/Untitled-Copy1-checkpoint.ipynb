# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
df=pd.read_csv("Healthcare_dataset.csv")
df.head()
# Out:
#   Ptid Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0   P1       Persistent    Male      Caucasian  Not Hispanic     West
# 1   P2   Non-Persistent    Male          Asian  Not Hispanic     West
# 2   P3   Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3   P4   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4   P5   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
#
#   Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0        >75  GENERAL PRACTITIONER              Others
# 1      55-65  GENERAL PRACTITIONER              Others
# 2      65-75  GENERAL PRACTITIONER              Others
# 3        >75  GENERAL PRACTITIONER              Others
# 4        >75  GENERAL PRACTITIONER              Others
#
#        Ntm_Speciality_Bucket Gluco_Record_Prior_Ntm Gluco_Record_During_Rx  \
# 0  OB/GYN/Others/PCP/Unknown                      N                      N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3424 entries, 0 to 3423
# Data columns (total 69 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Ptid                                                                3424 non-null   object
#  1   Persistency_Flag                                                    3424 non-null   object
#  2   Gender                                                              3424 non-null   object
#  3   Race                                                                3424 non-null   object
#  4   Ethnicity                                                           3424 non-null   object
#  5   Region                                                              3424 non-null   object
#  6   Age_Bucket                                                          3424 non-null   object
# ...

# %%
df.describe()
# Out:
#        Dexa_Freq_During_Rx  Count_Of_Risks
# count          3424.000000     3424.000000
# mean              3.016063        1.239486
# std               8.136545        1.094914
# min               0.000000        0.000000
# 25%               0.000000        0.000000
# 50%               0.000000        1.000000
# 75%               3.000000        2.000000
# max             146.000000        7.000000

# %%
# check NAN values 
pd.options.display.max_rows = 4000
df.isna().sum()
# Out:
# Ptid                                                                  0
# Persistency_Flag                                                      0
# Gender                                                                0
# Race                                                                  0
# Ethnicity                                                             0
# Region                                                                0
# Age_Bucket                                                            0
# Ntm_Speciality                                                        0
# Ntm_Specialist_Flag                                                   0
# Ntm_Speciality_Bucket                                                 0
# Gluco_Record_Prior_Ntm                                                0
# Gluco_Record_During_Rx                                                0
# Dexa_Freq_During_Rx                                                   0
# ...

# %%
# Unique per columns in the data set

print(df.apply(lambda col: col.unique()))
# Out:
# Ptid                                                                  [P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11,...
# Persistency_Flag                                                                           [Persistent, Non-Persistent]
# Gender                                                                                                   [Male, Female]
# Race                                                                  [Caucasian, Asian, Other/Unknown, African Amer...
# Ethnicity                                                                             [Not Hispanic, Hispanic, Unknown]
# Region                                                                 [West, Midwest, South, Other/Unknown, Northeast]
# Age_Bucket                                                                                     [>75, 55-65, 65-75, <55]
# Ntm_Speciality                                                        [GENERAL PRACTITIONER, Unknown, ENDOCRINOLOGY,...
# ...

# %%
# Start Exploratory data anlysis

# %%
# checking the gender counts of the patients 
gender_count= df.Gender.value_counts()
sns.countplot(x="Gender",data=df,palette="Set2")
print (gender_count)
# Out:
# Female    3230
# Male       194
# Name: Gender, dtype: int64

# %%
# checking the Persistency status counts of the patients 

persistency_count=df.Persistency_Flag.value_counts() 
sns.countplot(x="Persistency_Flag",data=df,palette="bright")
print (persistency_count)
# Out:
# Non-Persistent    2135
# Persistent        1289
# Name: Persistency_Flag, dtype: int64

# %%
# checking the region of the patients 

region_count= df.Region.value_counts() 
sns.countplot(x="Region",data=df,palette="husl") 
print (region_count)
# Out:
# Midwest          1383
# South            1247
# West              502
# Northeast         232
# Other/Unknown      60
# Name: Region, dtype: int64

# %%
# checking the Ethnicity of the patients

ethnicity_count=df.Ethnicity.value_counts() 

sns.countplot(x="Ethnicity",data=df)
print (ethnicity_count)
# Out:
# Not Hispanic    3235
# Hispanic          98
# Unknown           91
# Name: Ethnicity, dtype: int64

# %%
# checking the Age range of the patients in the study

age_count=df.Age_Bucket.value_counts() 

sns.countplot(x="Age_Bucket",data=df)
print (age_count)
# Out:
# >75      1439
# 65-75    1086
# 55-65     733
# <55       166
# Name: Age_Bucket, dtype: int64

# %%
# checking the Age range of the patients per Persistency status 

sns.countplot(x="Age_Bucket",hue="Persistency_Flag",data=df)
# Out:
# <AxesSubplot:xlabel='Age_Bucket', ylabel='count'>

# %%
# checking the gender of the patients per Persistency status 

sns.countplot(x="Gender",hue="Persistency_Flag",data=df,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# checking the Ethnicity of the patients per Persistency status 

sns.countplot(x="Ethnicity",hue="Persistency_Flag",data=df,palette="bright")
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
# checking the Region of the patients per Persistency status 

sns.countplot(x="Region",hue="Persistency_Flag",data=df,palette="husl")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
===========================================================

# %%
# checking the Region of the patients per Persistency status 

sns.countplot(x="Count_Of_Risks",hue="Persistency_Flag",data=df)
# Out:
# <AxesSubplot:xlabel='Count_Of_Risks', ylabel='count'>

# %%
df_diseases=pd.read_excel('Healthcare_dataset - diseases.xlsx',sheet_name='Dataset')
df_diseases.head()
# Out:
#   Persistency_Flag Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# 0       Persistent                                                  N
# 1   Non-Persistent                                                  N
# 2   Non-Persistent                                                  Y
# 3   Non-Persistent                                                  N
# 4   Non-Persistent                                                  Y
#
#   Comorb_Encounter_For_Immunization  \
# 0                                 Y
# 1                                 N
# 2                                 N
# 3                                 Y
# 4                                 Y
#
#   Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  Y
# 3                                                  Y
# ...

# %%
==========================================================

# %%
df_dummy_DA = pd.read_excel('Dataset_DA.xlsx',sheet_name= 'Dataset')

# %%
df1=pd.read_excel('Dataset_DA.xlsx',sheet_name= 'Dataset')
corr = df1.corr()
#corr_threshold=(corr>0.3) & (corr!= 1)
corr_threshold=(corr>0.0001) & (corr!= 1)

# %%
df_corr=pd.DataFrame(data=corr)
df_corr.head()
# Out:
#               Gender      Race  Ethnicity    Region  Age_Bucket  CARDIOLOGY  \
# Gender      1.000000 -0.011039  -0.029018  0.012035   -0.034688    0.003897
# Race       -0.011039  1.000000  -0.032984 -0.002231    0.034119    0.010005
# Ethnicity  -0.029018 -0.032984   1.000000  0.029735   -0.007203   -0.077094
# Region      0.012035 -0.002231   0.029735  1.000000    0.007492    0.010208
# Age_Bucket -0.034688  0.034119  -0.007203  0.007492    1.000000   -0.054224
#
#             CLINICAL NURSE SPECIALIST  EMERGENCY MEDICINE  ENDOCRINOLOGY  \
# Gender                       0.004189            0.004189      -0.022454
# Race                         0.002126            0.002126       0.037880
# Ethnicity                    0.000149            0.000149      -0.076925
# Region                       0.012335           -0.003639      -0.079650
# Age_Bucket                  -0.002066           -0.020984      -0.013320
#
# ...

# %%
pd.set_option('display.max_columns', None)
df_corr1=pd.DataFrame(data=corr_threshold)
df_corr1
# Out:
#                                                     Gender   Race  Ethnicity  \
# Gender                                               False  False      False
# Race                                                 False  False      False
# Ethnicity                                            False  False      False
# Region                                                True  False       True
# Age_Bucket                                           False   True      False
# CARDIOLOGY                                            True   True      False
# CLINICAL NURSE SPECIALIST                             True   True       True
# EMERGENCY MEDICINE                                    True   True       True
# ENDOCRINOLOGY                                        False   True      False
# GASTROENTEROLOGY                                      True   True       True
# GENERAL PRACTITIONER                                  True  False       True
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
df22=OneHotEncoder(drop='first').fit(df)

# %%
df22
# Out:
# OneHotEncoder(drop='first')

# %%
# maybe do detailed plots for the top
